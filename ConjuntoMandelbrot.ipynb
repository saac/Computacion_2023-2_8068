# %%
import cmath as cm
import numpy as np
import matplotlib.pyplot as plt

import random as rd

# %matplotlib notebook

# %%
z1 = 3+2j

# %%
a = 5
b = -7
z2 = complex(a,b)

# %%
type(z2)
# Out:
# complex

# %%
z2.imag
# Out:
# -7.0

# %%
x1 = z1.real
y1 = z1.imag

x2 = z2.real
y2 = z2.imag


plt.plot(x1,y1,'g.')
plt.plot(x2,y2,'r.')


plt.axhline(0, color='black')
plt.axvline(0, color='black')   
plt.grid()
# Out:
# <img src="data:image/png;base64,..." width="846.4">

# %%
X = [x1,x2]
Y = [y1,y2]

# %%
plt.plot(X,Y,'r.')
plt.axhline(0, color='black')
plt.axvline(0, color='black')   
plt.grid()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Reales = []
Imag = []

for x in np.arange(-10,11):
#     print(x
    Reales.append(x)

for i in range(-10,11):
#     print(i)
    Imag.append(i)

# %%
len(Reales)
# Out:
# 21

# %%
plt.plot(Reales,Imag,'m.')
plt.axhline(0, color='black')
plt.axvline(0, color='black')   
plt.grid()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
int(10*rd.random())
# Out:
# 9

# %%
R = []
I = []
n = 1000

for i in range(n):
    R.append(int(n*rd.random()))
    I.append(int(n*rd.random()))

# %%
plt.plot(R,I)
plt.plot(R,I,'r.')


plt.axhline(0, color='black')
plt.axvline(0, color='black')   
plt.grid()
# Out:
# <img src="data:image/png;base64,..." width="640">
